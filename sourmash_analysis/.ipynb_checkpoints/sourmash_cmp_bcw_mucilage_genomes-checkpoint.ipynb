# %% [markdown]
# ### Title: Sourmash Analysis of Mucilage Isolate Genomes
# ### Date: August 22, 2018
# ### Author: Shawn Higdon

# %%
ls
# Out:
# Genome_Comparison.ipynb
# bcw_all_k31_cmp
# bcw_all_k31_cmp.csv
# bcw_all_k31_cmp.labels.txt
# compare.py
# sourmash_cmp_bcw_mucilage_genomes.ipynb

# %%
# %matplotlib inline

# %%
import sourmash_lib.fig
import os
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch

# %%
mat, labels = sourmash_lib.fig.load_matrix_and_labels('bcw_all_k31_cmp')

# %%
bcw_k31_cmp_plot = sourmash_lib.fig.plot_composite_matrix(mat, labels)

# %%
bcw_k31_cmp_plot.set_size_inches(18.5, 13.5)
bcw_k31_cmp_plot

# %%
bcw_k31_cmp_plot.savefig('bcw_k31_cmp_plot.pdf')

# %%
pwd
# Out:
# '/Users/smhigdon/Box Sync/SMH_PhD/SMH_Thesis/Manuscripts/Manuscript_1/Isolate_Sourmash_Trees/sourmash_analysis'

# %%
ls
# Out:
# Genome_Comparison.ipynb     bcw_all_k31_cmp.labels.txt
# bcw_all_k31_cmp             compare.py
# bcw_all_k31_cmp.csv
